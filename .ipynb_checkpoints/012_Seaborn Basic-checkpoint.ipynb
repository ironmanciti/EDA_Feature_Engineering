# %% [markdown]
# # Seaborn 기초
#
# ### pandas DataFrame에 최적화된 plot 기능 제공
#
# ### 다음의 feature 를 제공
#
# - 내장된 테마
#
# - univariate 및 bivariate data 시각화
#
# - linear regression model 의 fitting 및 시각화
#
# - 통계적 시계열 data 의 plotting
#
# - Numpy 및 Pandas DataFrame 과 잘 연동
#
# - Matplotlib graphic 의 내장 theme 포함

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.rcParams['figure.figsize'] = (4, 3)

# %% [markdown]
# ## Seaborn style
# Seaborn에서 제공하는 스타일은 다음과 같습니다.
#
# darkgrid : default. 어두운 배경에 격자 라인이 그려진 스타일
# whitegrid : 밝은 배경에 격자 라인이 그려진 스타일
# dark : 어두운 배경에 격자 라인이 없는 스타일
# white : 밝은 배경에 격자 라인이 없는 스타일
# ticks : 축에 눈금이 있는 스타일

# %%
def sinplot():
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i))
        
sinplot()

# %% [markdown]
# ### seaborn 의 style 테마
#
#
# - Whitegrid
# - Dark
# - White
# - Ticks

# %%
sns.set_theme()  # default style="darkgrid"
sinplot()

# %%
sns.set_theme(style="whitegrid")
sinplot()

# %% [markdown]
# ### axis 의 top, right spine 제거
#
# - despine : 플롯에서 상단 및 오른쪽 스파인 제거.

# %%
sns.set_style("white")
fig, ax = plt.subplots()
sns.despine()
sinplot()

# %% [markdown]
# ## matplotlib 과 seaborn 의 DataFrame plot 비교
#
# seaborn의 내장 tips dataset 에서 요일별 평균 팁 금액을 남, 녀 고객 별로 비교해 봅니다.

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# day가 category type 인지 확인해 봅니다.

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ## matplotlib의 bar chart
#
# - Hard Way

# %% [markdown]
# day 열은 요일을 나타내며, 해당 열의 데이터는 Thur, Fri, Sat, Sun의 4가지 카테고리(분류)를 가집니다.

# %%
days = tips['day'].cat.categories
days
# Out:
# Index(['Thur', 'Fri', 'Sat', 'Sun'], dtype='object')

# %% [markdown]
# plot의 x 축에 사용할 array 값을 만듭니다.

# %%
x = np.arange(len(days))
x
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# tips 데이터셋에서 sex 열이 'Male'인 행만 추출한 후, day 열을 기준으로 그룹화하여 tip 열의 평균을 계산합니다.
#
# 따라서 이 코드를 실행하면, day 열의 각 카테고리별로, 성별로 손님이 지불한 팁(tip)의 평균값이 출력됩니다. 출력 결과는 day 열의 카테고리별로 총 4개의 값이 출력됩니다.

# %%
tip1 = tips[tips['sex'] == 'Male'].groupby('day').mean(numeric_only=True)['tip']
tip2 = tips[tips['sex'] == 'Female'].groupby('day').mean(numeric_only=True)['tip']

# %%
tip1
# Out:
# day
# Thur    2.980333
# Fri     2.693000
# Sat     3.083898
# Sun     3.220345
# Name: tip, dtype: float64

# %%
tip2
# Out:
# day
# Thur    2.575625
# Fri     2.781111
# Sat     2.801786
# Sun     3.367222
# Name: tip, dtype: float64

# %%
fig, ax = plt.subplots()
ax.bar(x, tip1, label='Male', tick_label=days, alpha=0.5)
ax.bar(x, tip2, label='Female', alpha=0.5)
ax.set_ylim([0, 4])
plt.legend(title="sex");

# %% [markdown]
# bar 의 사각형 범위를 조절하여 서로 겹치지 않도록 합니다.

# %%
fig, ax = plt.subplots()
ax.bar(x, tip1, width=-0.4, label='Male', tick_label=days, align='edge')
ax.bar(x, tip2, width=0.4, label='Female', align='edge')
ax.set_ylim([0, 4])
plt.legend(title="sex")

# %% [markdown]
# ## Seaborn의 barplot
#
# - Easy Way
# - 포인트 추정치 및 신뢰 구간을 직사각형 막대로 표시

# %%
sns.barplot(x="day", y="tip", data=tips, hue="sex", palette="winter_r")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.barplot(x="day", y="total_bill", data=tips, hue="smoker", ci=None) #ci - 신뢰구간
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(y="day", x="total_bill", data=tips, palette='spring', ci=None)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## 통계적 추론 (Statistical Estimation) 과 관련된 plot 들
#
# - 전체 data 의 분포에 대한 plotting
#
# - 중심경향 추론(central tendency estimation) 에 사용되는 mean 과 median 에 관련된 plot 들

# %% [markdown]
# ### boxplot - 범주와 관련된 분포를 표시하는 상자 그림
# 박스 플롯은 데이터의 분포를 시각화하는 그래프로, 데이터의 중앙값, 사분위수(Quartile), 이상치 등의 정보를 한눈에 파악할 수 있습니다

# %%
q1 = tips["total_bill"].quantile(0.25)   #1사분위수
q3 = tips["total_bill"].quantile(0.75)   #3사분위수
min_value = tips["total_bill"].min()    #최소값
median_value = tips["total_bill"].median()   #중간값
max_value = tips["total_bill"].max()   #최대값

iqr = q3 - q1   #IQR
limit_lower = q1 - 1.5*iqr    #1사분위수 - 1.5*iqr
limit_upper = q3 + 1.5*iqr   #3사분위수 + 1.5*iqr

print(f"1사분위수: {q1:.2f}, 중간값: {median_value:.2f}, 3사분위수: {q3:.2f}, IQR: {iqr:.2f}")
print(f"아래쪽 수염 limit {limit_lower:.2f}, 위쪽 수염 limit {limit_upper:.2f}")
print(f"최소값: {min_value:.2f}, 최대값: {max_value:.2f}")
# Out:
# 1사분위수: 13.35, 중간값: 17.80, 3사분위수: 24.13, IQR: 10.78
# 아래쪽 수염 limit -2.82, 위쪽 수염 limit 40.30
# 최소값: 3.07, 최대값: 50.81

# %% [markdown]
# matplotlib을 이용하여 boxplot을 그립니다.

# %%
plt.boxplot(tips["total_bill"])
plt.ylabel("total_bill")
plt.show()

# %% [markdown]
# seaborn을 이용하여 boxplot을 그립니다.

# %%
sns.boxplot(y="total_bill", data=tips);

# %%
ax = sns.boxplot(x="day", y="total_bill", data=tips)
ax.set_title("daily boxplot")
# Out:
# Text(0.5, 1.0, 'daily boxplot')

# %% [markdown]
# ### Violine Plot
#
# - box plot + kde (kernel density estimation) 을 하여 data 의 분포를 쉽게 파악할 수 있도록 합니다.
#
# - box plot 의 사분위수와 whisker 가 violin 내에 표시됩니다.
#
# - violin plot 이 kde 를 이용하므로 넓은 부분이 high density 이고, 좁은 부분이 low density 입니다.
#
# - Box plot 의 사분위간 범위(Inter-Quartile range) 와 kde 의 higher density 부분이 같은 영역으로 일치합니다.

# %% [markdown]
# 요일별 total bill 금액 분포를 파악합니다. x 축에 요일, y 축에 total bill을 지정합니다.

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# 요일별 성별 total bill 분를 파악합니다. x 축에 요일, y 축에 total bill을 남, 녀별로 plot을 표시합니다.

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.violinplot(x='day', y='total_bill', hue='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# `split=True`를 지정하면 하나의 violin plot을 반으로 분할하여 표시합니다.

# %%
fig, ax = plt.subplots(figsize=(8, 4))
sns.violinplot(x='day', y='total_bill', hue='sex', data=tips, split=True);
ax.legend(loc="upper center")

# %% [markdown]
# ## 변수 한개 (Univariate) 의 분포를 그리는 기능

# %% [markdown]
# seaborn에 내장된 붓꽃 데이터를 이용합니다.
#
# ### iris.feature_names :
#
# Sepal Length : 꽃받침 길이
# Sepal Width  : 꽃받침 너비
# Petal Length  : 꽃잎 길이
# Petal Width   :  꽃잎 너비
#
# Species (꽃의 종류) :  setosa / versicolor / virginica 의 3종류로 구분된다.
#
# 하나의 plot에 하나의 변수를 시각화 합니다.

# %%
df = sns.load_dataset('iris')

# %% [markdown]
# ### Histogram

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(df['petal_length'], ax=ax1)
ax1.set_title("petal length")
sns.histplot(df['petal_width'], ax=ax2)
ax2.set_title('petal width')
# Out:
# Text(0.5, 1.0, 'petal width')

# %% [markdown]
# ## 변수두개(bivariate) 분포를 그리는 기능

# %% [markdown]
# ### Joint Scatter Plot
#
# -  Seaborn의 sns.jointplot() 함수를 사용하면 두 개의 데이터 컬럼 간의 산점도와 히스토그램을 함께 볼 수 있습니다. 그리고 각 축의 x, y 라벨을 설정 할 수 있습니다.
#
# - Seaborn의 sns.jointplot() 함수는 기본적으로 산점도(scatter plot)를 그려주지만, kind 인자를 사용하면 그릴 그래프의 종류를 변경할 수 있습니다.
#
#     - 'scatter' : 산점도
#     - 'hex' : 헥스로그램
#     - 'kde' : 커널 밀도 추정
#     - 'reg' : 선형 회귀
#     - 'resid' : 잔차

# %% [markdown]
# ### jointplot()

# %%
ax = sns.jointplot(x='petal_length', y='petal_width', data=df)
ax.set_axis_labels('petal length', 'petal width')

# %% [markdown]
# ### Kernel Density Eestimation
#
# - 변수의 분포를 보는 방법

# %%
with sns.axes_style('white'):
    sns.jointplot(x='petal_length', y='petal_width', data=df, kind='kde')

# %% [markdown]
# ### Pairwise Relationship
#
# 데이터 분석에서는 변수들 간의 상관관계를 파악하는 것이 중요합니다. Seaborn 라이브러리에서는 pairplot 함수를 사용하여 데이터프레임의 변수들 간의 이차원 관계를 시각화할 수 있습니다. pairplot 함수는 데이터프레임의 모든 변수들을 이차원 평면에 나타내고, 각 변수들 간의 산점도(scatter plot)를 그립니다. 또한 대각선에는 변수들의 히스토그램(histogram)을 그려줍니다.
#
# - hue : 색깔 구분을 할 변수
# - diag_kind : 대각선에 배치할 subplots (hist or kde)

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
sns.pairplot(df, hue='species', diag_kind='kde', kind='scatter', palette='husl')

# %% [markdown]
# ### stripplot
#
# 하나의 변수가 범주형인 산점도입니다.
#
# stripplot 함수는 카테고리 변수와 연속형 변수 간의 관계를 시각화하는데 사용됩니다. stripplot 함수는 연속형 변수를 y축으로, 카테고리 변수를 x축으로 사용하여 데이터를 점으로 표시합니다.

# %%
sns.stripplot(x='species', y='petal_length', data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# 동일한 데이터를 boxplot으로 시각화할 때와 비교해 봅니다.

# %%
sns.boxplot(x='species', y='petal_length', data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>
